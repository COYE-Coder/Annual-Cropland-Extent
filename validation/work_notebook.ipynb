# %% [markdown]
# # Land Cover Validation Notebook
#
# ## Overview
# Validation workflow for classifying various land cover types including Agriculture, Non-Agriculture, and Urban areas. This data will be used to validate our agricultural land-use model (Crop Watch).
#
# 1) **Authenticate Earth Engine:** Run through the `ee.Authenticate()`` process.
# 2) **Define the working directory** This will be the directory that is to be examined
# 3) **Saving Work:** Once processing is complete, be sure to save the results to the master dataframe.
#
#
# **Note:** If you need to pause and continue later the same day, you can input the `exit` prompt to the program. Once you restart, it is a good idea to redefine the file path for today's work (e.g., `today2.csv`) upon resuming.

# %%
import geemap
import ee

# ee.Authenticate()
ee.Initialize()

# %%
from src.index_processing import *
from src.config import geo_lookup


# Who are you?
my_name = 'sean'

# Define the directory containing the tif files
base_directory = 'data/additional_points_from_GP/'
abs_directory_path = os.path.abspath(base_directory)

# Create a directory for your work today
date_directory = create_date_directory(abs_directory_path, my_name)

print(f"Directory you will be working in today: {date_directory}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Directory you will be working in today: /projects/land-use-validation/validation_git_test/Crop-Watch/validation/data/additional_points_from_GP/sean_2024-05-28

# %%
# Define appropriate folder according to current date
today_file_path = f'{date_directory}/today.csv'

# Define Appropriate master csv filepath
master_csv_path = f"{os.path.abspath('data/')}/{my_name}_master.csv"


# This is the main function 
#  - it will iterate over all files in base_directory -
# Have fun!
process_directory(directory=base_directory, geo_lookup=geo_lookup, 
                  csv_file_path = today_file_path, 
                  master_csv_path = master_csv_path)
# Out:
# Displaying file index 4802 at [-97.19147045050761, 46.937737163236505] in year 1995
# What type of landcover is this for index 4802?
#  (ur/ag/na/map/back/note/exit):  exit
# ======================================================
# Exiting the program. Thank you for your service
#
#                ****     ****
#              **    ** **    **
#             *       ***       *
#             *      , ___,     *
#             *      {O,o}     *
#              *     |)__)    *
#                *   -"-"   *
#                  *       *
#                     ***
#                      *
#             Owl be seeing you later!
#
# ======================================================
# ======================================================
# Here is what you have accomplished this session:
#   index                               coordinates landcover  year note
# 0  4828  [-109.63268797792092, 51.07582651953308]        ag  2008
# 1  4824  [-102.96539193918584, 39.47408462512946]        ag  2019
# 2  4816   [-90.77911628940564, 42.20891567610293]        na  1995
#   index                               coordinates landcover  year note
# 0  4828  [-109.63268797792092, 51.07582651953308]        ag  2008
# 1  4824  [-102.96539193918584, 39.47408462512946]        ag  2019
# 2  4816   [-90.77911628940564, 42.20891567610293]        na  1995

# %%
# Store the results from today's work onto the master csv
write_csv_to_master(today_file_path, master_csv_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Storing results from /projects/land-use-validation/false_true_index_chips/max_2024-03-20/today.csv to /projects/land-use-validation/max_master.csv
#        index                               coordinates landcover  year note  \
# 0      19462   [-120.46933474483994, 37.0790862461384]        ag  2015  NaN
# 1      11492   [-92.45806755542502, 35.91082721914096]        na  1998  NaN
# 2      18715   [-98.73378796181241, 38.08699599492051]        ag  2015  NaN
# 3      16591  [-108.63960043132678, 34.12785104322054]        na  1998  NaN
# 4      18767  [-95.80492080946912, 42.494310441867704]        na  1998  NaN
# ...      ...                                       ...       ...   ...  ...
# 11404  14181   [-89.63699823717607, 49.22763265398557]        na  2021  NaN
# 11405  13757  [-105.71504519234728, 22.59752521390442]        ag  1998  NaN
# 11406  18954  [-110.87559700502868, 47.98957452941205]        na  2021  NaN
# 11407   5635   [-120.3337789684663, 37.06183859268331]        ag  2003  NaN
# 11408  13428  [-99.03130998391279, 24.164636227050924]        ag  2003  NaN
#
#             _date
# 0      2024-02-14
# 1      2024-02-14
# 2      2024-02-14
# 3      2024-02-14
# 4      2024-02-14
# ...           ...
# 11404  2024-03-20
# 11405  2024-03-20
# 11406  2024-03-20
# 11407  2024-03-20
# 11408  2024-03-20
#
# [11409 rows x 6 columns]
